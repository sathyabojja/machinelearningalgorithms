# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data={
    'Area':[100,200,300,400,500],
    'Price':[1750,2750,3750,4750,5750]
}
df=pd.DataFrame(data)

# %%
df
# Out:
#    Area  Price
# 0   100   1750
# 1   200   2750
# 2   300   3750
# 3   400   4750
# 4   500   5750

# %%
plt.scatter(df.Area,df.Price,color='red')
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Area vs Price')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()

# %%
regressor.fit(df[['Area']],df.Price)
# Out:
# LinearRegression()

# %%
regressor.predict([[5665]])
# Out:
# C:\Users\sathy\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([57400.])

# %%
regressor.coef_
# Out:
# array([10.])

# %%
regressor.intercept_
# Out:
# 750.0

# %%
5665*10+750  #y=mx+c
# Out:
# 57400
