# %%
import pandas as pd
from sklearn.datasets import load_iris

# %%
iris=load_iris()

# %%
X=iris.data
y=iris.target

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)

# %%
X_pca = pca.fit_transform(X_scaled)

# %%
print("Shape after PCA:", X_pca.shape)
# Out:
# Shape after PCA: (150, 2)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis', edgecolor='k', s=70)
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('PCA on Iris Dataset (2D)')
plt.colorbar(label='Target Classes')
plt.grid(True)
plt.show()

# %% [markdown]
# What You Achieved in PCA Project:
# Loade--The Iris dataset with 4 features
# Standardized--The data using StandardScaler
# Reduced	Dimensions from 4D to 2D using PCA
# Visualize--Clear 2D clusters using scatter plot
# Analyzed	--How much variance was retained (~95%)
